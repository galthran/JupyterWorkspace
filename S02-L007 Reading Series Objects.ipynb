# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
pd.read_csv('./data/pokemon.csv')
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
nameSeries = pd.read_csv('./data/pokemon.csv', usecols=['Name'], squeeze=True)
nameSeries
# Out:
# /tmp/ipykernel_8277/1407571019.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   nameSeries = pd.read_csv('./data/pokemon.csv', usecols=['Name'], squeeze=True)
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
nameSeries = pd.read_csv('./data/pokemon.csv', usecols=['Name']).squeeze('columns')
nameSeries
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
speadSeries = pd.read_csv('./data/pokemon.csv', usecols=['Speed']).squeeze('columns')
speadSeries
# Out:
# 0       45
# 1       60
# 2       80
# 3       80
# 4       65
#       ...
# 795     50
# 796    110
# 797     70
# 798     80
# 799     70
# Name: Speed, Length: 800, dtype: int64

# %%
speadSeries.head()
# Out:
# 0    45
# 1    60
# 2    80
# 3    80
# 4    65
# Name: Speed, dtype: int64

# %%
speadSeries.size
# Out:
# 800

# %%
education = pd.read_csv('./data/developer_survey_2017/survey_results_public.csv', usecols=['FormalEducation'])

# %%
education.head()
# Out:
#                                      FormalEducation
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
# 3                                    Doctoral degree
# 4                                    Master's degree

# %%
type(education)
# Out:
# pandas.core.series.Series

# %%
education = pd.read_csv('./data/developer_survey_2017/survey_results_public.csv', usecols=['FormalEducation']).squeeze('columns')
education.head()
# Out:
# 0                                     Secondary school
# 1    Some college/university study without earning ...
# 2                                    Bachelor's degree
# 3                                      Doctoral degree
# 4                                      Master's degree
# Name: FormalEducation, dtype: object

# %%
education.tail(10)
# Out:
# 51382                                      Master's degree
# 51383               I never completed any formal education
# 51384                                    Bachelor's degree
# 51385                                      Master's degree
# 51386    Some college/university study without earning ...
# 51387                                    Bachelor's degree
# 51388                                      Master's degree
# 51389    Some college/university study without earning ...
# 51390                                    Bachelor's degree
# 51391                                    Bachelor's degree
# Name: FormalEducation, dtype: object

# %%
allInfo = pd.read_csv('./data/developer_survey_2017/survey_results_public.csv')
allInfo
# Out:
#        Respondent                                       Professional  \
# 0               1                                            Student
# 1               2                                            Student
# 2               3                             Professional developer
# 3               4  Professional non-developer who sometimes write...
# 4               5                             Professional developer
# ...           ...                                                ...
# 51387       51388                             Professional developer
# 51388       51389                                            Student
# 51389       51390                             Professional developer
# 51390       51391                             Professional developer
# 51391       51392  Professional non-developer who sometimes write...
#
#                     ProgramHobby         Country      University  \
# 0                      Yes, both   United States              No
# ...

# %%
country = allInfo['Country']
country
# Out:
# 0         United States
# 1        United Kingdom
# 2        United Kingdom
# 3         United States
# 4           Switzerland
#               ...
# 51387     United States
# 51388         Venezuela
# 51389            Canada
# 51390     United States
# 51391           Ireland
# Name: Country, Length: 51392, dtype: object

# %%
filterOnlyUSA = country.where(country == "United States").dropna()
filterOnlyUSA
# Out:
# 0        United States
# 3        United States
# 6        United States
# 10       United States
# 15       United States
#              ...
# 51380    United States
# 51381    United States
# 51384    United States
# 51387    United States
# 51390    United States
# Name: Country, Length: 11455, dtype: object

# %%
filterOnlyUSA = country == "United States"
education.where(filterOnlyUSA).dropna().head(10)
# Out:
# 0              Secondary school
# 3               Doctoral degree
# 6               Master's degree
# 10            Bachelor's degree
# 15    Primary/elementary school
# 17            Bachelor's degree
# 18            Bachelor's degree
# 25              Master's degree
# 27            Bachelor's degree
# 29            Bachelor's degree
# Name: FormalEducation, dtype: object
