# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
air = pd.read_csv("data/Air_Traffic_Passenger_Statistics.csv")

# %%
air.index
# Out:
# RangeIndex(start=0, stop=18398, step=1)

# %%
air.set_index(["Operating Airline","Activity Period"], inplace=True)

# %%
air.index
# Out:
# MultiIndex([(    'ATA Airlines', 200507),
#             (    'ATA Airlines', 200507),
#             (    'ATA Airlines', 200507),
#             (      'Air Canada', 200507),
#             (      'Air Canada', 200507),
#             (       'Air China', 200507),
#             (       'Air China', 200507),
#             (      'Air France', 200507),
#             (      'Air France', 200507),
#             ( 'Air New Zealand', 200507),
#             ...
#             (  'Virgin America', 201803),
#             (  'Virgin America', 201803),
#             (  'Virgin America', 201803),
#             ( 'Virgin Atlantic', 201803),
#             ( 'Virgin Atlantic', 201803),
#             ('Volaris Airlines', 201803),
#             ('Volaris Airlines', 201803),
#             (         'WOW Air', 201803),
#             (         'WOW Air', 201803),
#             (         'WOW Air', 201803)],
#            names=['Operating Airline', 'Activity Period'], length=18398)

# %%
air.index.get_level_values(0)
# Out:
# Index(['ATA Airlines', 'ATA Airlines', 'ATA Airlines', 'Air Canada',
#        'Air Canada', 'Air China', 'Air China', 'Air France', 'Air France',
#        'Air New Zealand',
#        ...
#        'Virgin America', 'Virgin America', 'Virgin America', 'Virgin Atlantic',
#        'Virgin Atlantic', 'Volaris Airlines', 'Volaris Airlines', 'WOW Air',
#        'WOW Air', 'WOW Air'],
#       dtype='object', name='Operating Airline', length=18398)

# %%
air.index.get_level_values(1)
# Out:
# Int64Index([200507, 200507, 200507, 200507, 200507, 200507, 200507, 200507,
#             200507, 200507,
#             ...
#             201803, 201803, 201803, 201803, 201803, 201803, 201803, 201803,
#             201803, 201803],
#            dtype='int64', name='Activity Period', length=18398)

# %%
air.index.names
# Out:
# FrozenList(['Operating Airline', 'Activity Period'])

# %%
air.reset_index()
# Out:
#       Operating Airline  Activity Period Operating Airline IATA Code  \
# 0          ATA Airlines           200507                          TZ
# 1          ATA Airlines           200507                          TZ
# 2          ATA Airlines           200507                          TZ
# 3            Air Canada           200507                          AC
# 4            Air Canada           200507                          AC
# ...                 ...              ...                         ...
# 18393  Volaris Airlines           201803                          Y4
# 18394  Volaris Airlines           201803                          Y4
# 18395           WOW Air           201803                          WW
# 18396           WOW Air           201803                          WW
# 18397           WOW Air           201803                          WW
#
#       Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# 0          ATA Airlines                          TZ       Domestic         US
# 1          ATA Airlines                          TZ       Domestic         US
# 2          ATA Airlines                          TZ       Domestic         US
# 3            Air Canada                          AC  International     Canada
# 4            Air Canada                          AC  International     Canada
# ...                 ...                         ...            ...        ...
# 18393  Volaris Airlines                          Y4  International     Mexico
# 18394  Volaris Airlines                          Y4  International     Mexico
# 18395           WOW Air                          WW  International     Europe
# 18396           WOW Air                          WW  International     Europe
# 18397           WOW Air                          WW  International     Europe
#
#       Activity Type Code Price Category Code       Terminal Boarding Area  \
# 0               Deplaned            Low Fare     Terminal 1             B
# 1               Enplaned            Low Fare     Terminal 1             B
# 2         Thru / Transit            Low Fare     Terminal 1             B
# 3               Deplaned               Other     Terminal 1             B
# 4               Enplaned               Other     Terminal 1             B
# ...                  ...                 ...            ...           ...
# 18393           Deplaned            Low Fare  International             A
# 18394           Enplaned            Low Fare  International             A
# 18395           Enplaned               Other  International             A
# 18396           Deplaned               Other  International             G
# 18397           Enplaned               Other  International             G
#
#        Passenger Count
# 0                27271
# 1                29131
# 2                 5415
# 3                35156
# 4                34090
# ...                ...
# 18393             4347
# 18394             4228
# 18395             4292
# 18396             2699
# 18397               10
#
# [18398 rows x 12 columns]

# %%
air.set_index("Published Airline",inplace=True)
air.head(10)
# Out:
#                   Operating Airline IATA Code Published Airline IATA Code  \
# Published Airline
# ATA Airlines                               TZ                          TZ
# ATA Airlines                               TZ                          TZ
# ATA Airlines                               TZ                          TZ
# Air Canada                                 AC                          AC
# Air Canada                                 AC                          AC
# Air China                                  CA                          CA
# Air China                                  CA                          CA
# Air France                                 AF                          AF
# Air France                                 AF                          AF
# Air New Zealand                            NZ                          NZ
#
#                      GEO Summary           GEO Region Activity Type Code  \
# Published Airline
# ATA Airlines            Domestic                   US           Deplaned
# ATA Airlines            Domestic                   US           Enplaned
# ATA Airlines            Domestic                   US     Thru / Transit
# Air Canada         International               Canada           Deplaned
# Air Canada         International               Canada           Enplaned
# Air China          International                 Asia           Deplaned
# Air China          International                 Asia           Enplaned
# Air France         International               Europe           Deplaned
# Air France         International               Europe           Enplaned
# Air New Zealand    International  Australia / Oceania           Deplaned
#
#                   Price Category Code       Terminal Boarding Area  \
# Published Airline
# ATA Airlines                 Low Fare     Terminal 1             B
# ATA Airlines                 Low Fare     Terminal 1             B
# ATA Airlines                 Low Fare     Terminal 1             B
# Air Canada                      Other     Terminal 1             B
# Air Canada                      Other     Terminal 1             B
# Air China                       Other  International             G
# Air China                       Other  International             G
# Air France                      Other  International             A
# Air France                      Other  International             A
# Air New Zealand                 Other  International             G
#
#                    Passenger Count
# Published Airline
# ATA Airlines                 27271
# ATA Airlines                 29131
# ATA Airlines                  5415
# Air Canada                   35156
# Air Canada                   34090
# Air China                     6263
# Air China                     5500
# Air France                   12050
# Air France                   11638
# Air New Zealand               4998

# %%
air.reset_index()
# Out:
#       Published Airline Operating Airline IATA Code  \
# 0          ATA Airlines                          TZ
# 1          ATA Airlines                          TZ
# 2          ATA Airlines                          TZ
# 3            Air Canada                          AC
# 4            Air Canada                          AC
# ...                 ...                         ...
# 18393  Volaris Airlines                          Y4
# 18394  Volaris Airlines                          Y4
# 18395           WOW Air                          WW
# 18396           WOW Air                          WW
# 18397           WOW Air                          WW
#
#       Published Airline IATA Code    GEO Summary GEO Region  \
# 0                              TZ       Domestic         US
# 1                              TZ       Domestic         US
# 2                              TZ       Domestic         US
# 3                              AC  International     Canada
# 4                              AC  International     Canada
# ...                           ...            ...        ...
# 18393                          Y4  International     Mexico
# 18394                          Y4  International     Mexico
# 18395                          WW  International     Europe
# 18396                          WW  International     Europe
# 18397                          WW  International     Europe
#
#       Activity Type Code Price Category Code       Terminal Boarding Area  \
# 0               Deplaned            Low Fare     Terminal 1             B
# 1               Enplaned            Low Fare     Terminal 1             B
# 2         Thru / Transit            Low Fare     Terminal 1             B
# 3               Deplaned               Other     Terminal 1             B
# 4               Enplaned               Other     Terminal 1             B
# ...                  ...                 ...            ...           ...
# 18393           Deplaned            Low Fare  International             A
# 18394           Enplaned            Low Fare  International             A
# 18395           Enplaned               Other  International             A
# 18396           Deplaned               Other  International             G
# 18397           Enplaned               Other  International             G
#
#        Passenger Count
# 0                27271
# 1                29131
# 2                 5415
# 3                35156
# 4                34090
# ...                ...
# 18393             4347
# 18394             4228
# 18395             4292
# 18396             2699
# 18397               10
#
# [18398 rows x 10 columns]

# %%
air.columns
# Out:
# Index(['Operating Airline IATA Code', 'Published Airline IATA Code',
#        'GEO Summary', 'GEO Region', 'Activity Type Code',
#        'Price Category Code', 'Terminal', 'Boarding Area', 'Passenger Count'],
#       dtype='object')
