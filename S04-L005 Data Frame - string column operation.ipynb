# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
fortune = pd.read_csv('data/Fortune_500_2017.csv')
fortune.head()
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
#
#         Sector                                  Industry         Hqlocation  \
# 0    Retailing                     General Merchandisers    Bentonville, AR
# 1   Financials  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2   Technology               Computers, Office Equipment      Cupertino, CA
# 3       Energy                        Petroleum Refining         Irving, TX
# 4  Wholesalers                  Wholesalers: Health Care  San Francisco, CA
#
#                    Hqaddr         Hqcity Hqstate  ...  \
# ...

# %%
fortune['Sector'] = fortune['Sector'].str.upper()

# %%
fortune.head()
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
#
#         Sector                                  Industry         Hqlocation  \
# 0    RETAILING                     General Merchandisers    Bentonville, AR
# 1   FINANCIALS  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2   TECHNOLOGY               Computers, Office Equipment      Cupertino, CA
# 3       ENERGY                        Petroleum Refining         Irving, TX
# 4  WHOLESALERS                  Wholesalers: Health Care  San Francisco, CA
#
#                    Hqaddr         Hqcity Hqstate  ...  \
# ...

# %%
fortune['Sector']
# Out:
# 0                       RETAILING
# 1                      FINANCIALS
# 2                      TECHNOLOGY
# 3                          ENERGY
# 4                     WHOLESALERS
#                   ...
# 495                     RETAILING
# 496    ENGINEERING & CONSTRUCTION
# 497                    TECHNOLOGY
# 498                        ENERGY
# 499             BUSINESS SERVICES
# Name: Sector, Length: 500, dtype: object

# %%
isIndustryContainsComp = fortune['Industry'].str.lower().str.contains('comp')

# %%
isCompIndustry
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: Industry, Length: 500, dtype: bool

# %%
fortune[isIndustryContainsComp]
# Out:
#      Rank                Title                            Website  Employees  \
# 2       3                Apple               http://www.apple.com     116000
# 27     28            Microsoft           http://www.microsoft.com     114000
# 40     41    Dell Technologies    http://www.delltechnologies.com     138000
# 46     47                Intel               http://www.intel.com     106000
# 60     61                   HP                  http://www.hp.com      49000
# 80     81               Oracle              http://www.oracle.com     136000
# 118   119             Qualcomm            http://www.qualcomm.com      30500
# 151   152        Jabil Circuit               http://www.jabil.com     138000
# 161   162                Xerox               http://www.xerox.com     133600
# 205   206    Texas Instruments                  http://www.ti.com      29865
# 216   217      Western Digital      http://www.westerndigital.com      72878
# ...

# %%
fortune[['City','State']] = fortune["Hqlocation"].str.split(",",expand=True)

# %%
fortune[['Hqlocation','City','State']]
# Out:
#             Hqlocation           City State
# 0      Bentonville, AR    Bentonville    AR
# 1            Omaha, NE          Omaha    NE
# 2        Cupertino, CA      Cupertino    CA
# 3           Irving, TX         Irving    TX
# 4    San Francisco, CA  San Francisco    CA
# ..                 ...            ...   ...
# 495         Irving, TX         Irving    TX
# 496        Horsham, PA        Horsham    PA
# 497      Sunnyvale, CA      Sunnyvale    CA
# 498         Dallas, TX         Dallas    TX
# 499       New York, NY       New York    NY
#
# [500 rows x 3 columns]

# %%
def BuildShortcut(row):
    industry = row['Industry']
    result = ""
    splitIndustry = industry.split(' ')
    for x in splitIndustry:
        result += x[0]
    return result

# %%
test = {'Industry':'Factory Under Newspaper'}

# %%
BuildShortcut(test)
# Out:
# 'FUN'

# %%
fortune[['IndustryShort']] = BuildShortcut(fortune)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_11038/1229334107.py in <module>
# ----> 1 fortune[['IndustryShort']] = BuildShortcut(fortune)
#
# /tmp/ipykernel_11038/397520334.py in BuildShortcut(row)
#       2     industry = row['Industry']
#       3     result = ""
# ----> 4     splitIndustry = industry.split(' ')
#       5     for x in splitIndustry:
#       6         result += x[0]
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'
